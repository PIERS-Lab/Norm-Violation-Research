# %%
import numpy
from matplotlib import pyplot as plt
import numpy as np

# %%
#preprocess
#pip install ipykernel

# %%
grid = plt.figure()
# dummy data
plt.xlim(-500, 500)
plt.ylim (-200, 500)
plt.plot(0, 0, 'ro')
plt.arrow(0, 0, 0, 1)
plt.plot(100, 150, 'ro')

# set graph color# dummy data
plt.xlim(-500, 500)
plt.ylim (-200, 500)
plt.plot(0, 0, 'ro')
plt.arrow(0, 0, 0, 1)
plt.plot(100, 150, 'ro')

# draws gridlines of grey color using given
# linewidth and linestyle
plt.grid(True, color = "grey", linewidth = "1.4", linestyle = "-.")

plt.show()
